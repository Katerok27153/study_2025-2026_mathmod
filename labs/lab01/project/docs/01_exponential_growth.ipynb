# %%
using DrWatson
@quickactivate "project"
using DifferentialEquations
using Plots
using DataFrames
function exponential_growth!(du, u, p, t)
α = p
du[1] = α * u[1]
end
u0 = [1.0] # начальная популяция
α = 0.3 # скорость роста
tspan = (0.0, 10.0) # временной интервал
prob = ODEProblem(exponential_growth!, u0, tspan, α)
sol = solve(prob, Tsit5(), saveat=0.1)
plot(sol, label="u(t)", xlabel="Время t", ylabel="Популяция u", title="Экспоненциальный рост (α = $α)", lw=2, legend=:topleft)
savefig(plotsdir("exponential_growth_α=$α.png"))
df = DataFrame(t=sol.t, u=first.(sol.u))
println("Первые 5 строк результатов:")
println(first(df, 5))
u_final = last(sol.u)[1]
doubling_time = log(2) / α
println("\nАналитическое время удвоения: ", round(doubling_time; digits=2))
# Out:
#   Activating project at `~/work/study/2025-2026/Математическое моделирование/mathmod/labs/lab01/project`
# Precompiling packages...
#   58463.8 ms  ✓ Plots
#   1 dependency successfully precompiled in 59 seconds. 175 already precompiled.
# Precompiling packages...
#    2889.6 ms  ✓ Plots → FileIOExt
#   1 dependency successfully precompiled in 4 seconds. 178 already precompiled.
# Precompiling packages...
#     527.9 ms  ✓ StructUtilsTablesExt (serial)
#   1 dependency successfully precompiled in 1 seconds
# Первые 5 строк результатов:
# 5×2 DataFrame
#  Row │ t        u
#      │ Float64  Float64
# ─────┼──────────────────
#    1 │     0.0  1.0
#    2 │     0.1  1.03045
#    3 │     0.2  1.06184
#    4 │     0.3  1.09417
#    5 │     0.4  1.1275
#
# Аналитическое время удвоения: 2.31

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
